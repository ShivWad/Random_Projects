# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')
features_data = data.columns
y = data['diagnosis']
data.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
features_with_null = [features for features in features_data if data[features].isnull().sum() > 1  ]

# %%
features_with_null
# Out:
# ['Unnamed: 32']

# %%
print(features_with_null , np.round(data[features_with_null].isnull().mean(),4), '% missing features')
# Out:
# ['Unnamed: 32'] Unnamed: 32    1.0
# dtype: float64 % missing features

# %%
X = data.drop(['Unnamed: 32'], axis = 1) 
features_data = dataset.columns
features_data
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
numerical_features = [features for features in features_data if dataset[features].dtype != 'O' ]

# %%
numerical_features
# Out:
# ['id',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst']

# %%
categprical_features = [feature for feature in features_data if dataset[feature].dtype == 'O']

# %%
categprical_features
# Out:
# ['diagnosis']

# %%
from sklearn.preprocessing import LabelBinarizer
encoder = LabelBinarizer()
encoder
# Out:
# LabelBinarizer(neg_label=0, pos_label=1, sparse_output=False)

# %%
dataset['encoded_diagnosis'] = encoder.fit_transform(dataset['diagnosis'])

# %%
y = dataset['encoded_diagnosis']

# %%
dataset = dataset.drop(['id', 'diagnosis', 'encoded_diagnosis'], axis = 1)

# %% [markdown]
# ## malignant = 1 and benign = 0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataset,y, test_size = 0.3 , random_state = 1)

# %%
X_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 249        11.52         14.93           73.87      406.3          0.10130
# 58         13.05         19.31           82.61      527.2          0.08060
# 476        14.20         20.53           92.41      618.4          0.08931
# 529        12.07         13.44           77.83      445.2          0.11000
# 422        11.61         16.02           75.46      408.2          0.10880
# ..           ...           ...             ...        ...              ...
# 129        19.79         25.12          130.40     1192.0          0.10150
# 144        10.75         14.97           68.26      355.3          0.07793
# 72         17.20         24.52          114.20      929.4          0.10710
# 235        14.03         21.25           89.79      603.4          0.09070
# 37         13.03         18.42           82.61      523.8          0.08983
#
# ...

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# s:\python\lib\site-packages\sklearn\linear_model\_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = model.predict(X_test)

# %%
score = model.score([y_pred],y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-8b27f94f0969> in <module>
# ----> 1 score = model.score([y_pred],y_test)
#
# s:\python\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     367         """
#     368         from .metrics import accuracy_score
# --> 369         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     370
#     371
#
# s:\python\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     291             Predicted class label per sample.
#     292         """
# --> 293         scores = self.decision_function(X)
#     294         if len(scores.shape) == 1:
#     295             indices = (scores > 0).astype(np.int)
#
# s:\python\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
#     270         n_features = self.coef_.shape[1]
# ...

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
